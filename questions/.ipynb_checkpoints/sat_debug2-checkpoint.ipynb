# %%
import json
import sys
import time
import urllib2
import subprocess
from IPython.core.debugger import set_trace

try:
    import requests
except ImportError:
    print "Please install the python-requests module."
    sys.exit(-1)

from requests.packages.urllib3.exceptions import InsecureRequestWarning
requests.packages.urllib3.disable_warnings(InsecureRequestWarning)

# %%
URL = 'https://vm255-149.gsslab.pnq2.redhat.com/'
SAT_API = 'https://vm255-149.gsslab.pnq2.redhat.com/'

USERNAME = "admin"
PASSWORD = "redhat"

SSL_VERIFY = False   # Ignore SSL for now
def get_json(url):
    # Performs a GET using the passed URL location
    r = requests.get(url, auth=(USERNAME, PASSWORD), verify=SSL_VERIFY)
    return r.json()

# %%
def get_results(url):
    jsn = get_json(url)
    if jsn.get('error'):
        print "Error: " + jsn['error']['message']
    else:
        if jsn.get('results'):
            return jsn['results']
        elif 'results' not in jsn:
            return jsn
        else:
            print "No results found"
    return None

# %%
def post_json(location):
    """
    Performs a POST and passes the data to the URL location
    """
    POST_HEADERS = {'content-type': 'application/json'}
    result = requests.post(
        location,
        auth=(USERNAME, PASSWORD),
        verify=SSL_VERIFY,
        headers=POST_HEADERS)

    return result.json()

# %%
def wait_for_sync(seconds):
#   repo_sync_tasks = "foreman_tasks/api/tasks?search=utf8=%E2%9C%93&search=label+%3D+Actions%3A%3AKatello%3A%3ARepository%3A%3ASync+and+state+%3D+running"
    repo_sync_tasks = "foreman_tasks/api/tasks?utf8=.&search=Actions%3A%3AKatello%3A%3ARepository%3A%3ASync+and+state+%3D+running"
    """
    Wait for all repo sync tasks to terminate. Search string is:
    label = Actions::Katello::Repository::Sync and state = running
    """

    count = 0
    print "Waiting for repo sync tasks to finish..."

    # Make sure that repo sync tasks gets the chance to appear before looking for them
    time.sleep(2)

    while get_json(URL + repo_sync_tasks)["total"] != 0:
        time.sleep(seconds)
        count += 1

    print "Repo Sync completed waiting after " + str(seconds * count) + " seconds"

# %%
def display_task_results(url):
    results = get_results(url)
    if results:
        #print results['output']
        out = results['humanized']['output']
    return out

# %%
def main():
    date=(time.strftime("%d-%m-%Y"))

    url=SAT_API + '/katello/api/products/248/repositories?organization_id=1'
    results=get_results(url)
    length=0
    for result in results:
        length=length+1
    data = [{'RepoID' : 'repo_id', 'RepoName' : 'Name', 'SyncID' : 'sync_id', 'Output' : 'out'} for k in range(length)]
    i=0
    for result in results:
        sync_url=SAT_API + '/katello/api/repositories/%d/sync' % result['id']
        sync_out=post_json(sync_url)
        data[i]['RepoID'] = result['id']
        data[i]['SyncID'] = sync_out['id']
        data[i]['RepoName'] = result['name']
        time.sleep(600)
        i=i+1
    wait_for_sync(10)
    set_trace()

    for k in range(0,i):
        output=display_task_results(SAT_API + 'foreman_tasks/api/tasks/%s' % data[k]['SyncID'])
        print output

# %%
if __name__ == "__main__":
    main()
# Out:
# Waiting for repo sync tasks to finish...
# Repo Sync completed waiting after 0 seconds
# > <ipython-input-7-859bf9676332>(23)main()
#      21     set_trace()
#      22
# ---> 23     for k in range(0,i):
#      24         output=display_task_results(SAT_API + 'foreman_tasks/api/tasks/%s' % data[k]['SyncID'])
#      25         print output
#
# ipdb> n
# > <ipython-input-7-859bf9676332>(24)main()
#      21     set_trace()
#      22
#      23     for k in range(0,i):
# ---> 24         output=display_task_results(SAT_API + 'foreman_tasks/api/tasks/%s' % data[k]['SyncID'])
#      25         print output
#
# ipdb> n
# > <ipython-input-7-859bf9676332>(25)main()
#      21     set_trace()
#      22
#      23     for k in range(0,i):
#      24         output=display_task_results(SAT_API + 'foreman_tasks/api/tasks/%s' % data[k]['SyncID'])
# ---> 25         print output
#
# ipdb> n
# No new packages.
# > <ipython-input-7-859bf9676332>(23)main()
#      21     set_trace()
#      22
# ---> 23     for k in range(0,i):
#      24         output=display_task_results(SAT_API + 'foreman_tasks/api/tasks/%s' % data[k]['SyncID'])
#      25         print output
#
# ipdb> n
# --Return--
# None
# > <ipython-input-7-859bf9676332>(23)main()
#      21     set_trace()
#      22
# ---> 23     for k in range(0,i):
#      24         output=display_task_results(SAT_API + 'foreman_tasks/api/tasks/%s' % data[k]['SyncID'])
#      25         print output
#
# ipdb> n
# --Return--
# None
# > <ipython-input-10-972361fa1b80>(2)<module>()
#       1 if __name__ == "__main__":
# ----> 2     main()
#
# ipdb> n
# > /usr/lib/python2.7/site-packages/IPython/core/interactiveshell.py(2881)run_code()
#    2879             finally:
#    2880                 # Reset our crash handler in place
# -> 2881                 sys.excepthook = old_excepthook
#    2882         except SystemExit as e:
#    2883             if result is not None:
#
# ipdb> n
# > /usr/lib/python2.7/site-packages/IPython/core/interactiveshell.py(2897)run_code()
#    2895             self.showtraceback()
#    2896         else:
# -> 2897             outflag = 0
#    2898         return outflag
#    2899
#
# ipdb> n
# > /usr/lib/python2.7/site-packages/IPython/core/interactiveshell.py(2898)run_code()
#    2896         else:
#    2897             outflag = 0
# -> 2898         return outflag
#    2899
#    2900     # For backwards compatibility
#
# ipdb> n
# --Return--
# 0
# > /usr/lib/python2.7/site-packages/IPython/core/interactiveshell.py(2898)run_code()
#    2896         else:
#    2897             outflag = 0
# -> 2898         return outflag
#    2899
#    2900     # For backwards compatibility
#
# ipdb> n
# > /usr/lib/python2.7/site-packages/IPython/core/interactiveshell.py(2815)run_ast_nodes()
#    2813
#    2814         try:
# -> 2815             for i, node in enumerate(to_run_exec):
#    2816                 mod = ast.Module([node])
#    2817                 code = compiler(mod, cell_name, "exec")
#
# ipdb> n
# > /usr/lib/python2.7/site-packages/IPython/core/interactiveshell.py(2821)run_ast_nodes()
#    2819                     return True
#    2820
# -> 2821             for i, node in enumerate(to_run_interactive):
#    2822                 mod = ast.Interactive([node])
#    2823                 code = compiler(mod, cell_name, "single")
#
# ipdb> n
# > /usr/lib/python2.7/site-packages/IPython/core/interactiveshell.py(2828)run_ast_nodes()
#    2826
#    2827             # Flush softspace
# -> 2828             if softspace(sys.stdout, 0):
#    2829                 print()
#    2830
# ipdb> n
# > /usr/lib/python2.7/site-packages/IPython/core/interactiveshell.py(2846)run_ast_nodes()
#    2844             return True
#    2845
# -> 2846         return False
#    2847
#    2848     def run_code(self, code_obj, result=None):
#
# ipdb> n
# --Return--
# False
# > /usr/lib/python2.7/site-packages/IPython/core/interactiveshell.py(2846)run_ast_nodes()
#    2844             return True
#    2845
# -> 2846         return False
#    2847
#    2848     def run_code(self, code_obj, result=None):
#
# ipdb> n
# > /usr/lib/python2.7/site-packages/IPython/core/interactiveshell.py(2716)run_cell()
#    2714                    interactivity=interactivity, compiler=compiler, result=result)
#    2715
# -> 2716                 self.last_execution_succeeded = not has_raised
#    2717
#    2718                 # Reset this so later displayed values do not modify the
#
# ipdb> n
# > /usr/lib/python2.7/site-packages/IPython/core/interactiveshell.py(2720)run_cell()
#    2718                 # Reset this so later displayed values do not modify the
#    2719                 # ExecutionResult
# -> 2720                 self.displayhook.exec_result = None
#    2721
#    2722                 self.events.trigger('post_execute')
#
# ipdb> n
# > /usr/lib/python2.7/site-packages/IPython/core/interactiveshell.py(2722)run_cell()
#    2720                 self.displayhook.exec_result = None
#    2721
# -> 2722                 self.events.trigger('post_execute')
#    2723                 if not silent:
#    2724                     self.events.trigger('post_run_cell')
#
# ipdb> n
# > /usr/lib/python2.7/site-packages/IPython/core/interactiveshell.py(2723)run_cell()
#    2721
#    2722                 self.events.trigger('post_execute')
# -> 2723                 if not silent:
#    2724                     self.events.trigger('post_run_cell')
#    2725
#
# ipdb> n
# > /usr/lib/python2.7/site-packages/IPython/core/interactiveshell.py(2724)run_cell()
#    2722                 self.events.trigger('post_execute')
#    2723                 if not silent:
# -> 2724                     self.events.trigger('post_run_cell')
#    2725
#    2726         if store_history:
#
# ipdb> n
# > /usr/lib/python2.7/site-packages/IPython/core/interactiveshell.py(2726)run_cell()
#    2724                     self.events.trigger('post_run_cell')
#    2725
# -> 2726         if store_history:
#    2727             # Write output to the database. Does nothing unless
#    2728             # history output logging is enabled.
#
# ipdb> n
# > /usr/lib/python2.7/site-packages/IPython/core/interactiveshell.py(2729)run_cell()
#    2727             # Write output to the database. Does nothing unless
#    2728             # history output logging is enabled.
# -> 2729             self.history_manager.store_output(self.execution_count)
#    2730             # Each cell is a *single* input, regardless of how many lines it has
#    2731             self.execution_count += 1
#
# ipdb> n
# > /usr/lib/python2.7/site-packages/IPython/core/interactiveshell.py(2731)run_cell()
#    2729             self.history_manager.store_output(self.execution_count)
#    2730             # Each cell is a *single* input, regardless of how many lines it has
# -> 2731             self.execution_count += 1
#    2732
#    2733         return result
#
# ipdb> n
# > /usr/lib/python2.7/site-packages/IPython/core/interactiveshell.py(2733)run_cell()
#    2731             self.execution_count += 1
#    2732
# -> 2733         return result
#    2734
#    2735     def transform_ast(self, node):
#
# ipdb> n
# --Return--
# <Executi...ult=None>
# > /usr/lib/python2.7/site-packages/IPython/core/interactiveshell.py(2733)run_cell()
#    2731             self.execution_count += 1
#    2732
# -> 2733         return result
#    2734
#    2735     def transform_ast(self, node):
#
# ipdb> n
# --Return--
# <Executi...ult=None>
# > /usr/lib/python2.7/site-packages/ipykernel/zmqshell.py(537)run_cell()
#     535     def run_cell(self, *args, **kwargs):
#     536         self._last_traceback = None
# --> 537         return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#     538
#     539     def _showtraceback(self, etype, evalue, stb):
# ipdb> n
# > /usr/lib/python2.7/site-packages/ipykernel/ipkernel.py(210)do_execute()
#     208             res = shell.run_cell(code, store_history=store_history, silent=silent)
#     209         finally:
# --> 210             self._restore_input()
#     211
#     212         if res.error_before_exec is not None:
#
# ipdb> n
# > /usr/lib/python2.7/site-packages/ipykernel/ipkernel.py(212)do_execute()
#     210             self._restore_input()
#     211
# --> 212         if res.error_before_exec is not None:
#     213             err = res.error_before_exec
#     214         else:
#
# ipdb>
